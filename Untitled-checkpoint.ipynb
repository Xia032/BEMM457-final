# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("LondonBikeJourneyAug2023.csv")
df.head()
# Out:
#       Number     Start date  Start station number  \
# 0  132825189  8/1/2023 0:00                  1190
# 1  132825190  8/1/2023 0:00                  1190
# 2  132825191  8/1/2023 0:00                   983
# 3  132825192  8/1/2023 0:01                  3479
# 4  132825193  8/1/2023 0:01                  1219
#
#                            Start station       End date  End station number  \
# 0  Kennington Lane Rail Bridge, Vauxhall  8/1/2023 0:17                1059
# 1  Kennington Lane Rail Bridge, Vauxhall  8/1/2023 0:17                1059
# 2                    Euston Road, Euston  8/1/2023 0:11                3500
# 3    Old Brompton Road, South Kensington  8/1/2023 0:12                1140
# 4                  Lower Marsh, Waterloo  8/1/2023 0:17              200056
#
#                    End station  Bike number Bike model Total duration  \
# 0  Albert Embankment, Vauxhall        23715    CLASSIC        16m 46s
# 1  Albert Embankment, Vauxhall        41267    CLASSIC        16m 47s
# 2   Baldwin Street, St. Luke's        53180    CLASSIC         11m 6s
# 3      Grosvenor Road, Pimlico        53431    CLASSIC        11m 53s
# 4      Vauxhall Walk, Vauxhall        54758    CLASSIC         16m 3s
#
#    Total duration (ms)
# 0              1006663
# 1              1007128
# 2               666395
# 3               713059
# 4               963786

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 776527 entries, 0 to 776526
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Number                776527 non-null  int64
#  1   Start date            776527 non-null  object
#  2   Start station number  776527 non-null  int64
#  3   Start station         776527 non-null  object
#  4   End date              776527 non-null  object
#  5   End station number    776527 non-null  int64
#  6   End station           776527 non-null  object
#  7   Bike number           776527 non-null  int64
#  8   Bike model            776527 non-null  object
#  9   Total duration        776527 non-null  object
#  10  Total duration (ms)   776527 non-null  int64
# dtypes: int64(5), object(6)
# memory usage: 65.2+ MB

# %%
df.describe()
# Out:
#              Number  Start station number  End station number    Bike number  \
# count  7.765270e+05          7.765270e+05        7.765270e+05  776527.000000
# mean   1.332250e+08          1.048377e+05        1.044439e+05   49568.888425
# std    2.307174e+05          1.277670e+05        1.278823e+05   13092.003305
# min    1.328252e+08          9.590000e+02        9.590000e+02       2.000000
# 25%    1.330252e+08          1.126000e+03        1.123000e+03   50563.000000
# 50%    1.332248e+08          3.467000e+03        3.465000e+03   54625.000000
# 75%    1.334248e+08          2.001800e+05        2.001810e+05   58168.000000
# max    1.336251e+08          1.100444e+06        1.100444e+06   61201.000000
#
#        Total duration (ms)
# count         7.765270e+05
# mean          1.554986e+06
# std           1.729002e+07
# min           1.307000e+03
# 25%           4.854690e+05
# 50%           8.387700e+05
# 75%           1.392228e+06
# max           7.441908e+09

# %%
df = df.drop_duplicates()

# %%
df.isna().sum()
# Out:
# Number                  0
# Start date              0
# Start station number    0
# Start station           0
# End date                0
# End station number      0
# End station             0
# Bike number             0
# Bike model              0
# Total duration          0
# Total duration (ms)     0
# dtype: int64

# %%
df = df.dropna()

# %%
df["Start date"] = pd.to_datetime(df["Start date"])

# %%
df["date"] = df["Start date"].dt.date
df["hour"] = df["Start date"].dt.hour

# %%
df = df[["Start date", "date", "hour", "Start station number", "End station number"]]

# %%
float(duration_mean), float(duration_median), float(duration_std)
# Out:
# (16.45479700742817, 13.583333333333334, 11.373474121489469)

# %%
daily_counts = df.groupby("date").size()

plt.figure(figsize=(10,5))
plt.plot(daily_counts.index, daily_counts.values)
plt.title("Daily Rentals")
plt.xlabel("Date")
plt.ylabel("Number of Rentals")
plt.grid(True)
plt.show()

# %%
hourly_counts = df.groupby("hour").size()

plt.figure(figsize=(10,5))
plt.plot(hourly_counts.index, hourly_counts.values)
plt.title("Hourly Rental")
plt.xlabel("Hour of Day")
plt.ylabel("Number of Rentals")
plt.grid(True)
plt.show()
